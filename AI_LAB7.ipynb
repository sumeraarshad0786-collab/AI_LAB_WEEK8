# %% [markdown]
# # import `mymodule.py`

# %%
import mymodule

# %% [markdown]
# # import whole module

# %%
print(mymodule.greet("Student"))  # Output: Hello, Student! Welcome to Week 8.
result = mymodule.add_numbers(5, 10)
print(f"The sum is: {result}")
# Out:
# Hello, Student! Welcome to Week 8.
# The sum is: 15

# %% [markdown]
# # import specific `functions`

# %%
from mymodule import greet, add_numbers
print(greet("Student"))
result = add_numbers(5, 10)
print(f"The sum is: {result}")
# Out:
# Hello, Student! Welcome to Week 8.
# The sum is: 15

# %% [markdown]
# # Built In Module `math` & `datetime`

# %%
import math
from datetime import datetime
 # Calculate square root
sqrt_value = math.sqrt(16)
print(f"Square root of 16: {sqrt_value}")  # 4.0
 # Use pi constant
circle_area = math.pi * (5 ** 2)
print(f"Area of circle with radius 5: {circle_area:.2f}")  # ~78.54
 # Current date/time and formatting
now = datetime.now()
print(f"Current date and time: {now}")
formatted_date = now.strftime('%Y-%m-%d %H:%M:%S')
print(f"Formatted: {formatted_date}")
# Out:
# Square root of 16: 4.0
# Area of circle with radius 5: 78.54
# Current date and time: 2025-10-31 12:46:59.722500
# Formatted: 2025-10-31 12:46:59

# %% [markdown]
# # Random module

# %%
import random, os
random_num = random.randint(1, 100)
with open('random_number.txt', 'w', encoding='utf-8') as file:
    file.write(str(random_num))
    print(f'Random number: {random_num}')
    print(f"Random number saved to: {os.path.abspath('random_number.txt')}")
# Out:
# Random number: 72
# Random number saved to: C:\Study Materials\Semester 3\Artificial Intelligence\AI-Lab-Work\Lab7\random_number.txt

# %% [markdown]
# # Requests

# %%
import requests

resp = requests.get('https://api.github.com', timeout=10)
if resp.status_code == 200:
        data = resp.json()
        # The top-level dict may not always contain 'rate'; print a couple of keys safely
        print('GitHub API Response (keys):', list(data.keys())[:5])
else:
        print(f'HTTP Error: {resp.status_code}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 3
#       1 import requests
# ----> 3 resp = requests.get('https://api.github.com', timeout=10)
#       4 if resp.status_code == 200:
#       5         data = resp.json()
#
# AttributeError: module 'requests' has no attribute 'get'

# %% [markdown]
# # Numpy `module`

# %%
try:
    import numpy as np
    arr = np.array([1, 2, 3])
    print('Array:', arr)
    print('Mean:', np.mean(arr))
except Exception as e:
    print('Numpy not available. Install with pip and retry.\n', e)
# Out:
# Numpy not available. Install with pip and retry.
#  module 'numpy' has no attribute 'array' (consider renaming 'C:\Study Materials\Semester 3\Artificial Intelligence\AI-Lab-Work\Lab7\numpy.py' if it has the same name as a library you intended to import)
